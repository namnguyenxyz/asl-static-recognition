# %% [markdown]
# # 01 — Dataset audit

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve(); sys.path.insert(0, str(ROOT))
from src.utils.config import load_config, ensure_output_dirs
from src.utils.labels import save_classes
from src.data.validate_dataset import audit_dataset
cfg = load_config(ROOT / 'configs/baseline.yaml'); ensure_output_dirs(cfg)
save_classes(cfg['classes'], ROOT / cfg['paths']['metadata'] / 'class_names.json')
audit = audit_dataset(ROOT / cfg['paths']['raw'], cfg['classes'], ROOT / cfg['paths']['metadata'])
display(audit.groupby(['label','status']).size().unstack(fill_value=0))
