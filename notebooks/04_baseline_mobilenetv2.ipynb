# %% [markdown]
# # 04 — MobileNetV2 baseline
# Backbone is frozen; this is the reference run for all later experiments.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve(); sys.path.insert(0, str(ROOT))
from src.utils.config import load_config
from src.models.train import train_baseline
cfg = load_config(ROOT / 'configs/baseline.yaml')
model, history = train_baseline(cfg)
model.summary()
