# %% [markdown]
# # 05 — Baseline evaluation
# The O/0 threshold is checked here against the untouched test split.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve(); sys.path.insert(0, str(ROOT))
from src.utils.config import load_config
from src.evaluation.evaluate import evaluate_model
result = evaluate_model(load_config(ROOT / 'configs/baseline.yaml'))
print(result)
if result['O_recall'] < .95 or result['0_recall'] < .95:
    print('Final O/0 target not met: continue with notebook 06 improvements.')
