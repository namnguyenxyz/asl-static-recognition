# %% [markdown]
# # 07 — Local realtime validation
# This notebook validates model loading and a single crop. Run the actual webcam app locally, not on a headless Colab GPU session.

# %%
from pathlib import Path
import sys, tensorflow as tf
ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve(); sys.path.insert(0, str(ROOT))
from src.utils.config import load_config
cfg = load_config(ROOT / 'configs/baseline.yaml')
model = tf.keras.models.load_model(ROOT / cfg['paths']['model'])
print('Model loaded:', model.name, 'input:', model.input_shape)
print('Run locally: python -m src.inference.webcam_demo')
